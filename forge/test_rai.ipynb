# %%
# %matplotlib inline
import matplotlib
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
import sys

import libry as lry

# %%
K = lry.Config()
D = K.view()
K.clear();
K.addFile('model/z.3.g')
